# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Store CSV into Dataframe

# %%
csv_file = "Resources/Happiness_2021.csv"
happy_df = pd.read_csv(csv_file, encoding='latin1')
happy_df.head()
# Out:
#   Country name     Capital Regional indicator  Ladder score  \
# 0      Finland    Helsinki     Western Europe         7.842
# 1      Denmark  Copenhagen     Western Europe         7.620
# 2  Switzerland        Bern     Western Europe         7.571
# 3      Iceland   Reykjavik     Western Europe         7.554
# 4  Netherlands   Amsterdam     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  ...  \
# 0                 10.775           0.954                     72.0  ...
# 1                 10.933           0.954                     72.7  ...
# 2                 11.117           0.942                     74.4  ...
# 3                 10.878           0.983                     73.0  ...
# 4                 10.932           0.942                     72.4  ...
#
#    Generosity  Perceptions of corruption  Ladder score in Dystopia  \
# 0      -0.098                      0.186                      2.43
# 1       0.030                      0.179                      2.43
# 2       0.025                      0.292                      2.43
# 3       0.160                      0.673                      2.43
# 4       0.175                      0.338                      2.43
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.446                         1.106
# 1                             1.502                         1.108
# 2                             1.566                         1.079
# 3                             1.482                         1.172
# 4                             1.501                         1.079
#
#    Explained by: Healthy life expectancy  \
# 0                                  0.741
# 1                                  0.763
# 2                                  0.816
# 3                                  0.772
# 4                                  0.753
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
# 1                                       0.686                     0.208
# 2                                       0.653                     0.204
# 3                                       0.698                     0.293
# 4                                       0.647                     0.302
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                    0.481                3.253
# 1                                    0.485                2.868
# 2                                    0.413                2.839
# 3                                    0.170                2.967
# 4                                    0.384                2.798
#
# [5 rows x 21 columns]

# %% [markdown]
# ### selecting only necessary columsn from CSV

# %%
happy_df = happy_df[['Capital', 'Country name', 'Ladder score', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy']]
happy_df
# Out:
#         Capital  Country name  Ladder score  Logged GDP per capita  \
# 0      Helsinki       Finland         7.842                 10.775
# 1    Copenhagen       Denmark         7.620                 10.933
# 2          Bern   Switzerland         7.571                 11.117
# 3     Reykjavik       Iceland         7.554                 10.878
# 4     Amsterdam   Netherlands         7.464                 10.932
# ..          ...           ...           ...                    ...
# 145    Gaborone      Botswana         3.467                  9.782
# 146      Kigali        Rwanda         3.415                  7.676
# 147      Harare      Zimbabwe         3.145                  7.943
# 148       Kabul   Afghanistan         2.523                  7.695
# 149         NaN  North Cyprus         5.536                 10.576
#
#      Social support  Healthy life expectancy
# 0             0.954                   72.000
# 1             0.954                   72.700
# 2             0.942                   74.400
# 3             0.983                   73.000
# 4             0.942                   72.400
# ..              ...                      ...
# 145           0.784                   59.269
# 146           0.552                   61.400
# 147           0.750                   56.201
# 148           0.463                   52.493
# 149           0.820                   73.898
#
# [150 rows x 6 columns]

# %% [markdown]
# ### renaming columns to match tables created in postgres

# %%
happy_df = happy_df.rename(columns={"Capital":"capital", "Country name":"country", "Ladder score":"happiness_score", "Logged GDP per capita":"gdp_per_capita",
                              "Social support":"social_support", "Healthy life expectancy":"healthy_life_expectancy"})
happy_df
# Out:
#         capital       country  happiness_score  gdp_per_capita  \
# 0      Helsinki       Finland            7.842          10.775
# 1    Copenhagen       Denmark            7.620          10.933
# 2          Bern   Switzerland            7.571          11.117
# 3     Reykjavik       Iceland            7.554          10.878
# 4     Amsterdam   Netherlands            7.464          10.932
# ..          ...           ...              ...             ...
# 145    Gaborone      Botswana            3.467           9.782
# 146      Kigali        Rwanda            3.415           7.676
# 147      Harare      Zimbabwe            3.145           7.943
# 148       Kabul   Afghanistan            2.523           7.695
# 149         NaN  North Cyprus            5.536          10.576
#
#      social_support  healthy_life_expectancy
# 0             0.954                   72.000
# 1             0.954                   72.700
# 2             0.942                   74.400
# 3             0.983                   73.000
# 4             0.942                   72.400
# ..              ...                      ...
# 145           0.784                   59.269
# 146           0.552                   61.400
# 147           0.750                   56.201
# 148           0.463                   52.493
# 149           0.820                   73.898
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Checking for Null values

# %%
happy_df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   capital                  149 non-null    object
#  1   country                  150 non-null    object
#  2   happiness_score          150 non-null    float64
#  3   gdp_per_capita           150 non-null    float64
#  4   social_support           150 non-null    float64
#  5   healthy_life_expectancy  150 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 7.2+ KB

# %% [markdown]
# ### one null value in capital, wanto to drop that

# %%
happy_df = happy_df.dropna()

# %% [markdown]
# ### recheck nulls

# %%
happy_df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149 entries, 0 to 148
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   capital                  149 non-null    object
#  1   country                  149 non-null    object
#  2   happiness_score          149 non-null    float64
#  3   gdp_per_capita           149 non-null    float64
#  4   social_support           149 non-null    float64
#  5   healthy_life_expectancy  149 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 8.1+ KB

# %%
happy_df.set_index('capital')
happy_df
# Out:
#         capital      country  happiness_score  gdp_per_capita  social_support  \
# 0      Helsinki      Finland            7.842          10.775           0.954
# 1    Copenhagen      Denmark            7.620          10.933           0.954
# 2          Bern  Switzerland            7.571          11.117           0.942
# 3     Reykjavik      Iceland            7.554          10.878           0.983
# 4     Amsterdam  Netherlands            7.464          10.932           0.942
# ..          ...          ...              ...             ...             ...
# 144      Maseru      Lesotho            3.512           7.926           0.787
# 145    Gaborone     Botswana            3.467           9.782           0.784
# 146      Kigali       Rwanda            3.415           7.676           0.552
# 147      Harare     Zimbabwe            3.145           7.943           0.750
# 148       Kabul  Afghanistan            2.523           7.695           0.463
#
#      healthy_life_expectancy
# 0                     72.000
# 1                     72.700
# 2                     74.400
# 3                     73.000
# 4                     72.400
# ..                       ...
# 144                   48.700
# 145                   59.269
# 146                   61.400
# 147                   56.201
# 148                   52.493
#
# [149 rows x 6 columns]

# %% [markdown]
# ### Doing all of the above for the weather data

# %%
csv_file = "Resources/weather.csv"
weather_df = pd.read_csv(csv_file, encoding='latin1')
weather_df.head()
# Out:
#    Unnamed: 0        city   temp  Minimum_Temp  Maximum_Temp Country
# 0           0    Helsinki  49.19         46.99         51.01      FI
# 1           1  Copenhagen  51.96         50.00         54.00      DK
# 2           2        Bern  68.09         66.99         69.80      CH
# 3           3   Reykjavik  42.64         42.01         43.00      IS
# 4           4   Amsterdam  50.16         48.99         51.01      NL

# %%
weather_df = weather_df[['city', 'temp', 'Minimum_Temp', 'Maximum_Temp']]
weather_df
# Out:
#            city   temp  Minimum_Temp  Maximum_Temp
# 0      Helsinki  49.19         46.99         51.01
# 1    Copenhagen  51.96         50.00         54.00
# 2          Bern  68.09         66.99         69.80
# 3     Reykjavik  42.64         42.01         43.00
# 4     Amsterdam  50.16         48.99         51.01
# ..          ...    ...           ...           ...
# 143      Maseru  57.85         57.85         57.85
# 144    Gaborone  73.40         73.40         73.40
# 145      Kigali  73.40         73.40         73.40
# 146      Harare  71.01         71.01         71.01
# 147       Kabul  71.60         71.60         71.60
#
# [148 rows x 4 columns]

# %%
weather_df = weather_df.rename(columns={"city": "capital", "Minimum_Temp":"min_temp", "Maximum_Temp":"max_temp"})
weather_df
# Out:
#         capital   temp  min_temp  max_temp
# 0      Helsinki  49.19     46.99     51.01
# 1    Copenhagen  51.96     50.00     54.00
# 2          Bern  68.09     66.99     69.80
# 3     Reykjavik  42.64     42.01     43.00
# 4     Amsterdam  50.16     48.99     51.01
# ..          ...    ...       ...       ...
# 143      Maseru  57.85     57.85     57.85
# 144    Gaborone  73.40     73.40     73.40
# 145      Kigali  73.40     73.40     73.40
# 146      Harare  71.01     71.01     71.01
# 147       Kabul  71.60     71.60     71.60
#
# [148 rows x 4 columns]

# %%
weather_df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   capital   148 non-null    object
#  1   temp      148 non-null    float64
#  2   min_temp  148 non-null    float64
#  3   max_temp  148 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 4.8+ KB

# %%
weather_df.set_index('capital')
weather_df
# Out:
#         capital   temp  min_temp  max_temp
# 0      Helsinki  49.19     46.99     51.01
# 1    Copenhagen  51.96     50.00     54.00
# 2          Bern  68.09     66.99     69.80
# 3     Reykjavik  42.64     42.01     43.00
# 4     Amsterdam  50.16     48.99     51.01
# ..          ...    ...       ...       ...
# 143      Maseru  57.85     57.85     57.85
# 144    Gaborone  73.40     73.40     73.40
# 145      Kigali  73.40     73.40     73.40
# 146      Harare  71.01     71.01     71.01
# 147       Kabul  71.60     71.60     71.60
#
# [148 rows x 4 columns]

# %% [markdown]
# ### Connect to postgres

# %%
rds_connection_string = "postgres:postgres@localhost:5432/happiness_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ### check for tables

# %%
engine.table_names()
# Out:
# ['weather', 'happy']

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
happy_df.to_sql(name='happy', con=engine, if_exists='append', index=False)

# %% [markdown]
# ## checking to see if it worked

# %%
pd.read_sql_query('select * from happy', con=engine).head()
# Out:
#       capital      country  happiness_score  gdp_per_capita  social_support  \
# 0    Helsinki      Finland            7.842          10.775           0.954
# 1  Copenhagen      Denmark            7.620          10.933           0.954
# 2        Bern  Switzerland            7.571          11.117           0.942
# 3   Reykjavik      Iceland            7.554          10.878           0.983
# 4   Amsterdam  Netherlands            7.464          10.932           0.942
#
#    healthy_life_expectancy
# 0                     72.0
# 1                     72.7
# 2                     74.4
# 3                     73.0
# 4                     72.4

# %% [markdown]
# ### doing the same for the weather dataframe

# %%
weather_df.to_sql(name = 'weather', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from weather', con=engine).head()
# Out:
#       capital   temp  min_temp  max_temp
# 0    Helsinki  49.19     46.99     51.01
# 1  Copenhagen  51.96     50.00     54.00
# 2        Bern  68.09     66.99     69.80
# 3   Reykjavik  42.64     42.01     43.00
# 4   Amsterdam  50.16     48.99     51.01
