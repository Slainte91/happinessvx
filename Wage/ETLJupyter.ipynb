# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "happiness_bycountry.csv"
happiness_df = pd.read_csv(csv_file)

# %%
happiness_df.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
happiness_df = happiness_df[['Country','Happiness.Rank','Happiness.Score']]

happiness_df
# Out:
#                       Country  Happiness.Rank  Happiness.Score
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
# [155 rows x 3 columns]

# %%
len(happiness_df['Country'])
# Out:
# 155

# %%
csv_file = "wages_bycountry.csv"
wages_df = pd.read_csv(csv_file)

# %%
wages_df.head(5)


lines = wages_df['Gross Average Monthly Wages by Country and Year']

# %%
lines=lines[1:]

# %%
def country_wage(row):
    i = 32
    country1=""
    while(i<len(row)):
        country1 = country1+row[i]
        i=i+1
        if (row[i] == ";"):
            break;
    country=country1[:-1] 
    country

    wage = ""
    i=i+1;
    while(i<len(row)):
        wage = wage+row[i]
        i=i+1


    return country,wage

# %%
country_list=[]
wage_list=[]
for line in lines:
    country,wage = country_wage(line)
    country_list.append(country)
    wage_list.append(wage)

# %%
wage_df = pd.DataFrame(list(zip(country_list,wage_list)), columns=['Country' , 'Wage'])

wage_df
# Out:
#                    Country    Wage
# 0                  Albania      ..
# 1                  Andorra      ..
# 2                  Armenia   404.1
# 3                  Austria  4034.2
# 4               Azerbaijan   307.1
# 5                  Belarus      ..
# 6                  Belgium  4127.2
# 7   Bosnia and Herzegovina   761.2
# 8                 Bulgaria      ..
# 9                   Canada  4174.4
# 10                 Croatia  1219.2
# 11                  Cyprus  2137.6
# 12                 Czechia  1285.6
# 13                 Denmark  5487.1
# 14                 Estonia  1379.4
# 15                 Finland  3906.1
# 16                  France  3541.8
# 17                 Georgia   398.1
# 18                 Germany  3713.6
# 19                  Greece  1632.1
# 20                 Hungary  1045.2
# 21                 Iceland      ..
# 22                 Ireland  4435.6
# 23                  Israel  2735.0
# 24                   Italy  2750.2
# 25              Kazakhstan   462.7
# ...

# %%
new_dataset = pd.merge(happiness_df,wage_df , how ='inner')
new_dataset
# Out:
#                    Country  Happiness.Rank  Happiness.Score    Wage
# 0                   Norway               1            7.537  5492.0
# 1                  Denmark               2            7.522  5487.1
# 2                  Iceland               3            7.504      ..
# 3              Switzerland               4            7.494  7351.7
# 4                  Finland               5            7.469  3906.1
# 5              Netherlands               6            7.377  4401.6
# 6                   Canada               7            7.316  4174.4
# 7                   Sweden               9            7.284  3990.4
# 8                   Israel              11            7.213  2735.0
# 9                  Austria              13            7.006  4034.2
# 10           United States              14            6.993  5046.5
# 11                 Ireland              15            6.977  4435.6
# 12                 Germany              16            6.951  3713.6
# ...

# %%
new_dataset=new_dataset[new_dataset.Wage !='..']
new_dataset
# Out:
#                    Country  Happiness.Rank  Happiness.Score    Wage
# 0                   Norway               1            7.537  5492.0
# 1                  Denmark               2            7.522  5487.1
# 3              Switzerland               4            7.494  7351.7
# 4                  Finland               5            7.469  3906.1
# 5              Netherlands               6            7.377  4401.6
# 6                   Canada               7            7.316  4174.4
# 7                   Sweden               9            7.284  3990.4
# 8                   Israel              11            7.213  2735.0
# 9                  Austria              13            7.006  4034.2
# 10           United States              14            6.993  5046.5
# 11                 Ireland              15            6.977  4435.6
# 12                 Germany              16            6.951  3713.6
# 13                 Belgium              17            6.891  4127.2
# ...

# %%
new_dataset.to_csv("new_dataset.csv" , index = False , header = True)
